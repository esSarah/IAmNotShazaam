# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,  client_secret= config.client_secret))

# %%
playlist = sp.user_playlist_tracks("spotify", "6ajZ3ZK5HL1peecsWjWZ7Y",offset=99,market="GB")

# %%
playlist["href"]
# Out:
# 'https://api.spotify.com/v1/playlists/6ajZ3ZK5HL1peecsWjWZ7Y/tracks?offset=99&limit=100&market=GB&additional_types=track'

# %%
playlist["items"][0]["track"]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37394IP6uhnjIpsawpMu4l'},
#     'href': 'https://api.spotify.com/v1/artists/37394IP6uhnjIpsawpMu4l',
#     'id': '37394IP6uhnjIpsawpMu4l',
#     'name': 'Killswitch Engage',
#     'type': 'artist',
#     'uri': 'spotify:artist:37394IP6uhnjIpsawpMu4l'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3oh7MlSbfeka5mnnQdbLeO'},
#   'href': 'https://api.spotify.com/v1/albums/3oh7MlSbfeka5mnnQdbLeO',
#   'id': '3oh7MlSbfeka5mnnQdbLeO',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dcf96f7c3fc19956de7aa109',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dcf96f7c3fc19956de7aa109',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dcf96f7c3fc19956de7aa109',
#     'width': 64}],
#   'name': 'Alive or Just Breathing',
# ...

# %%
the_end_is_neigh = True
current_offset=0
counter_over_all_entries = 0
while(the_end_is_neigh):
    playlist = sp.user_playlist_tracks("spotify", "6ajZ3ZK5HL1peecsWjWZ7Y",offset=current_offset,market="GB")
    current_offset += 99
    for i in range(0,len(playlist["items"])):
        print(str(current_offset) + "   " + str(playlist["items"][i]["track"]["name"]))
        counter_over_all_entries += 1
    if(i!=99):
        the_end_is_neigh = False
# Out:
# 99   Numbered Days
# 99   Self Revolution
# 99   Fixation on the Darkness
# 99   My Last Serenade
# 99   Life to Lifeless
# 99   Just Barely Breathing
# 99   To the Sons of Man
# 99   Temple from the Within
# 99   The Element of One
# 99   Vide Infra
# 99   Without a Name
# 99   Rise Inside
# 99   Where Are You? - Remastered
# 99   The Night We Called It A Day - Remastered
# 99   I Cover The Waterfront - Remastered
# 99   Maybe You'll Be There - Remastered
# 99   Laura - Remastered
# 99   Lonely Town - Remastered
# 99   Autumn Leaves - 1999 / Digital Remaster
# 99   I'm A Fool To Want You - Remastered
# 99   I Think Of You - Remastered
# 99   Where Is The One? - Remastered
# 99   There's No You - Remastered
# 99   Baby, Won't You Please Come Home - Remastered
# 99   I Can Read Between The Lines - Remastered
# 99   It Worries Me - Remastered
# 99   Rain (Falling From The Skies) - Remastered
# 99   Don't Worry 'Bout Me - 1999 Remastered
# ...
