# %% [markdown]
# # I am not Shazaam
# ### Find new Music suggesting by text or even by the music itself

# %%
import pandas as pd
import i_am_not_shazaam_hidden

# %%
i_am = i_am_not_shazaam_hidden.hidden()
Top_100 = i_am.get_top_100()
search_data_dataframe = i_am.init_cluster()

# %%
recommend_me_something_for_this = input("Please enter a song to base a recommendation on ")
# Out:
# Please enter a song to base a recommendation on A boy named sue

# %% [markdown]
# ### If you want to record a sample instead, type "shazaam"

# %%
i_am.find_match(recommend_me_something_for_this, Top_100)
# Out:
# Please select a number regarding the many titles of this name

# %%
pd.DataFrame(i_am.search_selector_list)
# Out:
#        0                                                  1     2  \
# 0    [1]  A Boy Named Sue - Live at San Quentin State Pr...   [2]
# 1                                               Johnny Cash
# 2    [6]  A Boy Named Sue - Live at Nassau Coliseum, Uni...   [7]
# 3         The Highwaymen, Willie Nelson, Johnny Cash, Wa...
# 4   [11]                                        One Big Mob  [12]
# 5                                     Red Hot Chili Peppers
# 6   [16]                                        One Big Mob  [17]
# 7                                     Red Hot Chili Peppers
# 8   [21]                                    The Outlaw Ways  [22]
# 9                                  Hank 3 & David Allan Coe
# 10  [26]                           Little Lil' - Remastered  [27]
# 11            The Hillbilly Moon Explosion, Emanuela Hutter
# 12  [31]                                      Boy Named Sue  [32]
# 13                                         Shel Silverstein
# ...

# %%
i_am.song_selected = input("which number do you choose? ") if i_am.results_are_a_list and i_am.there_is_a_track_id else False
# Out:
# which number do you choose? 10

# %%
i_am.get_match()
# Out:
#                    Title                      id  cluster
# 248  Of Lions and Wolves  4eRxYL2PycfoxWeyujM16A       17

# %%
from IPython.display import IFrame

IFrame(src="https://open.spotify.com/embed/track/"+i_am.track_id,
   width="320",
   height="80",
   frameborder="0",
   allowtransparency="true",
   allow="encrypted-media",
  )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/4eRxYL2PycfoxWeyujM16A?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### sometimes a direct Spotify sampling is possible, see here
