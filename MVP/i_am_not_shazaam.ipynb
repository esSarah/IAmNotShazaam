# %% [markdown]
# # I am not Shazaam
# ### Find new Music suggesting by text or even by the music itself

# %%
import pandas as pd
import i_am_not_shazaam_hidden

# %%
i_am = i_am_not_shazaam_hidden.hidden()
Top_100 = i_am.get_top_100()
search_data_dataframe = i_am.init_cluster()
# Out:
# ../models/scaler.pickle

# %%
recommend_me_something_for_this = input("Please enter a song to base a recommendation on ")
# Out:
# Please enter a song to base a recommendation on shazaam

# %% [markdown]
# ### If you want to record a sample instead, type "shazaam"

# %%
i_am.find_match(recommend_me_something_for_this, Top_100)
# Out:
# recording for 5 seconds
# Starting: Play music now!
# finished
# that was "Let Her Go" from Jasmine Thompson
# Let Her Go Jasmine Thompson
# Please select a number regarding the many titles of this name

# %%
pd.DataFrame(i_am.search_selector_list)
# Out:
#        0                                                  1     2  \
# 0    [1]                                         Let Her Go   [2]
# 1                                                 Passenger
# 2    [6]                      Let Her Go (Acoustic Version)   [7]
# 3                                                 Passenger
# 4   [11]                                         Let Her Go  [12]
# 5                             Boyce Avenue, Hannah Trigwell
# 6   [16]                                         Let Her Go  [17]
# 7                                                     6LACK
# 8   [21]  I Bet You Think About Me (feat. Chris Stapleto...  [22]
# 9                             Taylor Swift, Chris Stapleton
# 10  [26]                                         Be Alright  [27]
# 11                                               Dean Lewis
# 12  [31]                                         Let Her Go  [32]
# 13                             Rio Branco, Bossanova Covers
# 14  [36]                                       Neck & Wrist  [37]
# 15                        Pusha T, JAY-Z, Pharrell Williams
# 16  [41]     Neck & Wrist (feat. JAY-Z & Pharrell Williams)  [42]
# 17                        Pusha T, JAY-Z, Pharrell Williams
# 18  [46]     Hey Baby (Drop It to the Floor) (feat. T-Pain)  [47]
# 19                                          Pitbull, T-Pain
#
#                                                  3     4  \
# 0                    Let Her Go (Acoustic Version)   [3]
# 1                                        Passenger
# 2                                     Eenie Meenie   [8]
# 3                     Sean Kingston, Justin Bieber
# 4                                       Let Her Go  [13]
# 5                                      Mac DeMarco
# 6                                       Let Her Go  [18]
# 7                                    Purple Tulips
# 8                                       Let Her Go  [23]
# 9                                      Henry Smith
# 10                               Thinking out Loud  [28]
# 11                                      Ed Sheeran
# 12  Neck & Wrist (feat. JAY-Z & Pharrell Williams)  [33]
# 13               Pusha T, JAY-Z, Pharrell Williams
# 14  Neck & Wrist (feat. JAY-Z & Pharrell Williams)  [38]
# 15               Pusha T, JAY-Z, Pharrell Williams
# 16                                      Let Her Go  [43]
# 17           Lofi Fruits Music, Fets, Orange Stick
# 18                                      Let Her Go  [48]
# 19                                         fenekot
#
#                               5     6  \
# 0                    Let Her Go   [4]
# 1                 The Kid LAROI
# 2                    Let Her Go   [9]
# 3       Behmer, B3nte, The High
# 4   Shoota (feat. Lil Uzi Vert)  [14]
# 5   Playboi Carti, Lil Uzi Vert
# 6                  Livin' Thing  [19]
# 7      Electric Light Orchestra
# 8                      Lollipop  [24]
# 9                          MIKA
# 10                   Let Her Go  [29]
# 11         Music Lab Collective
# 12                   Let her go  [34]
# 13                   Ygkaymusic
# 14                   Let Her Go  [39]
# 15  Scotch Butter, TIVON, Lenji
# 16                   Let Her Go  [44]
# 17   Nylonwings, Rudi Salisbury
# 18       REPEAT IT (with Gunna)  [49]
# 19             Lil Tecca, Gunna
#
#                                                  7     8  \
# 0                                       Be Alright   [5]
# 1                                       Dean Lewis
# 2                                       Let Her Go  [10]
# 3                                 Jasmine Thompson
# 4                                       Let Her Go  [15]
# 5                                  David Fischbein
# 6                                       Let Her Go  [20]
# 7                                        Passenger
# 8                                       Let Her Go  [25]
# 9            Lofi Fruits Music, Fets, Orange Stick
# 10             The Way Life Goes (feat. Oh Wonder)  [30]
# 11                         Lil Uzi Vert, Oh Wonder
# 12  Neck & Wrist (feat. JAY-Z & Pharrell Williams)  [35]
# 13               Pusha T, JAY-Z, Pharrell Williams
# 14  Neck & Wrist (feat. JAY-Z & Pharrell Williams)  [40]
# 15               Pusha T, JAY-Z, Pharrell Williams
# 16                                Need You Tonight  [45]
# 17                              JP Cooper, RAY BLK
# 18                                      Let Her Go  [50]
# 19                                   Dual Sessions
#
#                                                  9
# 0                                       Let Her Go
# 1                             LANDR, Ruuben, Walle
# 2                                       Be Alright
# 3                                       Dean Lewis
# 4   Neck & Wrist (feat. JAY-Z & Pharrell Williams)
# 5                Pusha T, JAY-Z, Pharrell Williams
# 6                                       Let Her Go
# 7                                   Jonathan Sipal
# 8                                       Be Alright
# 9                                       Dean Lewis
# 10                               Hey There Delilah
# 11                                 Plain White T's
# 12                                      Let Her Go
# 13                               Music Travel Love
# 14                                      Let Her Go
# 15                 Piano Fruits Music, Ludvig Hall
# 16                                      Let Her Go
# 17                 Horizon Blue, Music Travel Love
# 18                                  Tag, You're It
# 19                                Melanie Martinez

# %%
i_am.song_selected = input("which number do you choose? ") if i_am.results_are_a_list and i_am.there_is_a_track_id else False
# Out:
# which number do you choose? 1

# %%
i_am.get_match()
# Out:
#         Title                      id  cluster
# 7238  Shadows  61QO7Fn6yFM6Ek3TFO6C0O       17

# %%
from IPython.display import IFrame

IFrame(src="https://open.spotify.com/embed/track/"+i_am.track_id,
   width="320",
   height="80",
   frameborder="0",
   allowtransparency="true",
   allow="encrypted-media",
  )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/61QO7Fn6yFM6Ek3TFO6C0O?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### sometimes a direct Spotify sampling is possible, see here
