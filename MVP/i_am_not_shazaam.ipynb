# %%
import config
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import combine_dataframe

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from matplotlib import pyplot
import numpy as np
import pickle

import i_am_not_shazaam_hidden as i_am
# Out:
# prepared

# %%
Top_100 = i_am.get_top_100()
search_data_dataframe = i_am.init_cluster()

# %%
Top_100[["place","song","artists"]]
# Out:
#     place          song                   artists
# 0       1     As It Was              Harry Styles
# 1       2   First Class               Jack Harlow
# 2       3    Heat Waves             Glass Animals
# 3       4    Big Energy                     Latto
# 4       5         Enemy     Imagine Dragons X JID
# ..    ...           ...                       ...
# 95     96       P Power     Gunna Featuring Drake
# 96     97  Money So Big                      Yeat
# 97     98  Blick Blick!   Coi Leray & Nicki Minaj
# 98     99  Fall In Love          Bailey Zimmerman
# 99    100  X Ultima Vez  Daddy Yankee & Bad Bunny
#
# [100 rows x 3 columns]

# %%
recommend_me_something_for_this = input("Please enter a song to base a recommendation on ")
# Out:
# Please enter a song to base a recommendation on fuzz

# %%
i_am.find_match(recommend_me_something_for_this, Top_100)
# Out:
# Please select a number regarding the many titles of this name

# %%
pd.DataFrame(i_am.search_selector_list)
# Out:
#        0                    1     2  \
# 0    [1]           Fuzzybrain   [2]
# 1                     Dayglow
# 2    [6]     Run the World!!!   [7]
# 3                     Dayglow
# 4   [11]   Caught By the Fuzz  [12]
# 5                  Supergrass
# 6   [16]  Fuzzy Little Kitten  [17]
# 7               Jesse Birkman
# 8   [21]          Fuzzy Wuzzy  [22]
# 9                       TIMMS
# 10  [26]     White Noise Fuzz  [27]
# 11             Crafting Audio
# 12  [31]                Fuzzy  [32]
# 13                 courtship.
# 14  [36]     White Noise Fuzz  [37]
# 15             Crafting Audio
# 16  [41]     White Noise Fuzz  [42]
# 17             Crafting Audio
# 18  [46]     White Noise Fuzz  [47]
# 19             Crafting Audio
#
#                                                     3     4  \
# 0                             Can I Call You Tonight?   [3]
# 1                                             Dayglow
# 2                                               Fuzzy   [8]
# ...

# %%
there_is_a_track_id, results_are_a_list, track_id = i_am.isTrack_isList_TrackID()
print(str( i_am.isTrack_isList_TrackID()))

song_selected = input("which number do you choose? ") if results_are_a_list and there_is_a_track_id else False
# Out:
# (False, False, '')

# %%
song_selected = input("which number do you choose? ") if results_are_a_list and there_is_a_track_id else Fals

# %%
i_am.get_match()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 i_am.get_match()
#
# File ~\Documents\DataAnalytisc\IAmNotShazaam\MVP\i_am_not_shazaam_hidden.py:221, in get_match()
#     218 #print(str(selection_features))
#     219 list_of_one = []
#     220 list_values_of_one = [
# --> 221     selection_features[0]['danceability'],
#     222     selection_features[0]['energy'],
#     223     selection_features[0]['key'],
#     224     selection_features[0]['loudness'],
#     225     selection_features[0]['mode'],
#     226     selection_features[0]['speechiness'],
#     227     selection_features[0]['acousticness'],
#     228     selection_features[0]['instrumentalness'],
#     229     selection_features[0]['liveness'],
#     230     selection_features[0]['valence'],
#     231     selection_features[0]['tempo']
#     232 ]
# ...

# %%
# Out:
# ''

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"


IFrame(src="https://open.spotify.com/embed/track/"+i_am.track_id,
   width="320",
   height="80",
   frameborder="0",
   allowtransparency="true",
   allow="encrypted-media",
  )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
