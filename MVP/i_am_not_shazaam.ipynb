# %% [markdown]
# # I am not Shazaam
# ### Find new Music suggesting by text or even by the music itself

# %%
import pandas as pd
import i_am_not_shazaam_hidden

# %%
i_am = i_am_not_shazaam_hidden.hidden()
Top_100 = i_am.get_top_100()
search_data_dataframe = i_am.init_cluster()

# %%
recommend_me_something_for_this = input("Please enter a song to base a recommendation on ")
# Out:
# Please enter a song to base a recommendation on sway with me

# %% [markdown]
# ### If you want to record a sample instead, type "shazaam"

# %%
i_am.find_match(recommend_me_something_for_this, Top_100)
# Out:
# Please select a number regarding the many titles of this name

# %%
pd.DataFrame(i_am.search_selector_list)
# Out:
#        0                            1     2                                3  \
# 0    [1]  Sway With Me (with GALXARA)   [2]                       Levitating
# 1                   Saweetie, GALXARA                       Dua Lipa, DaBaby
# 2    [6]                   Levitating   [7]      Sway With Me (with GALXARA)
# 3                    Dua Lipa, DaBaby                      Saweetie, GALXARA
# 4   [11]                   Levitating  [12]                     Sway with Me
# 5                    Dua Lipa, DaBaby                          Shotgun Rider
# 6   [16]                Glad You Came  [17]  (Mucho Mambo) Sway - Radio Edit
# 7                          The Wanted                                  Shaft
# 8   [21]                 Sway With Me  [22]                       Levitating
# 9                        Yuppie Blick                               Dua Lipa
# 10  [26]                         Sway  [27]                        Come & Go
# 11                      Michael Bublé                                 ArrDee
# 12  [31]    Levitating (feat. DaBaby)  [32]               Mucho Mambo - Sway
# 13                   Dua Lipa, DaBaby                                  Shaft
# 14  [36]                         Sway  [37]                   Move Your Body
# 15                        Tove Styrke                         Öwnboss, Sevek
# 16  [41]                 Stay With Me  [42]                   Mixed Emotions
# 17                          Sam Smith                           Abra Cadabra
# 18  [46]  Rule The World - Radio Edit  [47]                 I Like Me Better
# 19                          Take That                                   Lauv
#
#        4                                                  5     6  \
# 0    [3]                              Sway With Me (slowed)   [4]
# 1                                                  mohammix
# 2    [8]                                       Sway With Me   [9]
# 3                                              Yossi Azulay
# 4   [13]                          Levitating (feat. DaBaby)  [14]
# 5                                          Dua Lipa, DaBaby
# 6   [18]  One More Chance / Stay with Me - Remix; 2007 R...  [19]
# 7                                      The Notorious B.I.G.
# 8   [23]              Sway (with Pérez Prado y Su Orquesta)  [24]
# 9                             Rosemary Clooney, Pérez Prado
# 10  [28]                                               Sway  [29]
# 11                                       The Pussycat Dolls
# 12  [33]                                     Rock Your Body  [34]
# 13                                        Justin Timberlake
# 14  [38]                                               Sway  [39]
# 15                                                Glee Cast
# 16  [43]                                       Stay With Me  [44]
# 17                                                   1nonly
# 18  [48]                                         Poker Face  [49]
# 19                                                Lady Gaga
#
#                                     7     8                               9
# 0                          Levitating   [5]  Sway With Me - GALXARA Version
# 1                    Dua Lipa, DaBaby                               GALXARA
# 2                          Levitating  [10]                    Sway with me
# 3                    Dua Lipa, DaBaby                      Hitkend ChillLab
# 4                   Sway (Quien Sera)  [15]                   swaying dream
# 5                         Dean Martin              Jeffu, with me, with you
# 6                        Stay With Me  [20]     Sway With Me (with GALXARA)
# 7                           Sam Smith                     Saweetie, GALXARA
# 8               Stay With Me (FYH301)  [25]                        Everlong
# 9   Far Out, Nikhil Prakash, CeCe Mix                          Foo Fighters
# 10              Islands In the Stream  [30]                            Sway
# 11         Dolly Parton, Kenny Rogers                           Dean Martin
# 12               Sway - Junkie XL Mix  [35]            What's My Age Again?
# 13           Michael Bublé, Junkie XL                             blink-182
# 14                      One Last Time  [40]                    Sway With Me
# 15                      Ariana Grande               Bill Haley & His Comets
# 16      Rocking A Cardigan in Atlanta  [45]                   What the Hell
# 17                  lil Shordie Scott                         Avril Lavigne
# 18                  Come Away With Me  [50]                        Don't Go
# 19                        Norah Jones             D-Block Europe, Wretch 32

# %%
i_am.song_selected = input("which number do you choose? ") if i_am.results_are_a_list and i_am.there_is_a_track_id else Fals
# Out:
# which number do you choose? 39

# %%
i_am.get_match()
# Out:
#     Title                      id  cluster
# 439    Eh  5pNYiMbnXm7UkewX2KhmyK       16

# %%
from IPython.display import IFrame

IFrame(src="https://open.spotify.com/embed/track/"+i_am.track_id,
   width="320",
   height="80",
   frameborder="0",
   allowtransparency="true",
   allow="encrypted-media",
  )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/5pNYiMbnXm7UkewX2KhmyK?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### sometimes a direct Spotify sampling is possible, see here
